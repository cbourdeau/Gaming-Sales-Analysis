# %% [markdown]
# # Heroes Of Pymoli Data Analysis
# * Of the 1163 active players, the vast majority are male (84%). There also exists, a smaller, but notable proportion of female players (14%).
#
# * Our peak age demographic falls between 20-24 (44.8%) with secondary groups falling between 15-19 (18.60%) and 25-29 (13.4%).
# -----

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data_df = pd.read_csv(file_to_load)

# %% [markdown]
# ## Player Count
# #### Key-Takeaways:
# * There are 576 unique players that have made purchases within Heroes of Pymoli

# %%
# Create data frame to display total number of unique players
Total_Unique_Players_df = pd.DataFrame({"Total # of Players" : [purchase_data_df["SN"].nunique()]})
Total_Unique_Players_df
# Out:
#    Total # of Players
# 0                 576

# %% [markdown]
# ## Purchasing Analysis
# #### Key-Takeaways:
#
# * There was 183 unique items sold
# * The average sale was 3.05 dollars
# * There was 780 in-game sales
# * Total revenues/sales were 2,379.77 dollars

# %%
# find total number of unique items, average purchase price, number of purchases, and total revenue
total_unique = purchase_data_df["Item ID"].nunique() 
avg_price = purchase_data_df["Price"].mean()
total_pur = purchase_data_df["Purchase ID"].count()
total_rev = purchase_data_df["Price"].sum()

# create Purchase Analysis DataFrame to display results
pur_analysis = pd.DataFrame([{
    "Number of Unique Items": total_unique,
    "Average Purchase Price": avg_price,
    "Number of Purchases": total_pur,
    "Total Revenue": total_rev}])

# reorder columns
pur_analysis = pur_analysis[["Number of Unique Items", "Average Purchase Price", "Number of Purchases", "Total Revenue"]]

# format data frame
pur_analysis.style.format({"Average Purchase Price": '${:.2f}',
                           "Total Revenue": '${:,.2f}'})
# Out:
#         <style  type="text/css" >
#
#
#         </style>
#
#         <table id="T_53b2f5ba_9d75_11e9_a816_d43d7ebc6f16" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   Number of Unique Items
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   Average Purchase Price
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   Number of Purchases
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   Total Revenue
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_53b2f5ba_9d75_11e9_a816_d43d7ebc6f16"
#                  class="row_heading level0 row0" rowspan=1>
#                     0
#
#
#
#                 <td id="T_53b2f5ba_9d75_11e9_a816_d43d7ebc6f16row0_col0"
#                  class="data row0 col0" >
#                     183
#
#
#
#                 <td id="T_53b2f5ba_9d75_11e9_a816_d43d7ebc6f16row0_col1"
#                  class="data row0 col1" >
#                     $3.05
#
#
#
#                 <td id="T_53b2f5ba_9d75_11e9_a816_d43d7ebc6f16row0_col2"
#                  class="data row0 col2" >
#                     780
#
#
#
#                 <td id="T_53b2f5ba_9d75_11e9_a816_d43d7ebc6f16row0_col3"
#                  class="data row0 col3" >
#                     $2,379.77
#
#
#             </tr>
#
#         </tbody>
#         </table>

# %% [markdown]
# ## Gender Demographics
# #### Key-Takeaways:
# * Males = 84% (484)
# * Females = 14% (81)
# * Other = 2% (11)

# %%
# create a data frame of unique players by dropping Screen Name douplicates
no_dup_sn = purchase_data_df.drop_duplicates(["SN"])

# calculate total count of each gender and each respective percentage
plyr_count_by_gen = no_dup_sn.groupby("Gender")["SN"].count()
pct_of_plyrs_by_gen = plyr_count_by_gen / no_dup_sn["Gender"].count()

# consolidate series data from above into a dataframe
gender_demos_df = pd.DataFrame({
    "Total Count" : plyr_count_by_gen,
    "Percent of Players" : pct_of_plyrs_by_gen,})

# reorder columns
gender_demos_df = gender_demos_df[["Total Count", "Percent of Players"]]

# sort data frame by "Total Count"
sorted_gender_demos_df = gender_demos_df.sort_values("Total Count", ascending = False)

# format data frame
formatted_gender_demos_df = sorted_gender_demos_df.style.format({"Percent of Players" : "{:.02%}"})
formatted_gender_demos_df
# Out:
#         <style  type="text/css" >
#
#
#         </style>
#
#         <table id="T_a765a14c_9d77_11e9_a145_d43d7ebc6f16" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   Total Count
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   Percent of Players
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th class="index_name level0" >
#                   Gender
#
#
#
#                 <th class="blank" >
#
#
#
#
#                 <th class="blank" >
#
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_a765a14c_9d77_11e9_a145_d43d7ebc6f16"
#                  class="row_heading level0 row0" rowspan=1>
#                     Male
#
#
#
#                 <td id="T_a765a14c_9d77_11e9_a145_d43d7ebc6f16row0_col0"
#                  class="data row0 col0" >
#                     484
#
#
#
#                 <td id="T_a765a14c_9d77_11e9_a145_d43d7ebc6f16row0_col1"
#                  class="data row0 col1" >
#                     84.03%
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_a765a14c_9d77_11e9_a145_d43d7ebc6f16"
#                  class="row_heading level0 row1" rowspan=1>
#                     Female
#
#
#
#                 <td id="T_a765a14c_9d77_11e9_a145_d43d7ebc6f16row1_col0"
#                  class="data row1 col0" >
#                     81
#
#
#
#                 <td id="T_a765a14c_9d77_11e9_a145_d43d7ebc6f16row1_col1"
#                  class="data row1 col1" >
#                     14.06%
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_a765a14c_9d77_11e9_a145_d43d7ebc6f16"
#                  class="row_heading level0 row2" rowspan=1>
#                     Other / Non-Disclosed
#
#
#
#                 <td id="T_a765a14c_9d77_11e9_a145_d43d7ebc6f16row2_col0"
#                  class="data row2 col0" >
#                     11
#
#
#
#                 <td id="T_a765a14c_9d77_11e9_a145_d43d7ebc6f16row2_col1"
#                  class="data row2 col1" >
#                     1.91%
#
#
#             </tr>
#
#         </tbody>
#         </table>

# %% [markdown]
# ## Purchasing Analysis (Gender)
# #### Key-Takeaways:
# * Males drove the most sales (1,967.94)
# * Males had x5.7 more buyers than Females

# %%
# calculate purchase count, avg. purchase price, total purchase value, 
# and avg. purchase total per person by gender
pc_grpby = purchase_data_df.groupby("Gender")["Purchase ID"].count() 
app_grpby = purchase_data_df.groupby("Gender")["Price"].mean() 
pur_val_grpby = purchase_data_df.groupby("Gender")["Price"].sum() 
avg_pur_person_grpby= pur_val_grpby / no_dup_sn.groupby("Gender")["Price"].count()

# consolidate series data from above into a dataframe to 
# display Purchasing Analysis (Gender)
pur_analysis_gen = pd.DataFrame({
    "Purchase Count" : pc_grpby,
    "Average Purchase Price" : app_grpby,
    "Total Purchase Value" : pur_val_grpby,
    "Avg Purchase Total per Person" : avg_pur_person_grpby})

# reorder columns
pur_analysis_gen = pur_analysis_gen[["Purchase Count", "Average Purchase Price","Total Purchase Value", "Avg Purchase Total per Person"]]

# sort data in decending order based on purchase count
sorted_pur_analysis = pur_analysis_gen.sort_values("Purchase Count", ascending = False)

# format data frame
sorted_pur_analysis.style.format({
    "Average Purchase Price" : "${:.2f}",
    "Total Purchase Value" : "${:.2f}",
    "Avg Purchase Total per Person" : "${:.2f}"})
# Out:
#         <style  type="text/css" >
#
#
#         </style>
#
#         <table id="T_7d9ced58_9d77_11e9_8e44_d43d7ebc6f16" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   Purchase Count
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   Average Purchase Price
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   Total Purchase Value
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   Avg Purchase Total per Person
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th class="index_name level0" >
#                   Gender
#
#
#
#                 <th class="blank" >
#
#
#
#
#                 <th class="blank" >
#
#
#
#
#                 <th class="blank" >
#
#
#
#
#                 <th class="blank" >
#
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_7d9ced58_9d77_11e9_8e44_d43d7ebc6f16"
#                  class="row_heading level0 row0" rowspan=1>
#                     Male
#
#
#
#                 <td id="T_7d9ced58_9d77_11e9_8e44_d43d7ebc6f16row0_col0"
#                  class="data row0 col0" >
#                     652
#
#
#
#                 <td id="T_7d9ced58_9d77_11e9_8e44_d43d7ebc6f16row0_col1"
#                  class="data row0 col1" >
#                     $3.02
#
#
#
#                 <td id="T_7d9ced58_9d77_11e9_8e44_d43d7ebc6f16row0_col2"
#                  class="data row0 col2" >
#                     $1967.64
#
#
#
#                 <td id="T_7d9ced58_9d77_11e9_8e44_d43d7ebc6f16row0_col3"
#                  class="data row0 col3" >
#                     $4.07
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_7d9ced58_9d77_11e9_8e44_d43d7ebc6f16"
#                  class="row_heading level0 row1" rowspan=1>
#                     Female
#
#
#
#                 <td id="T_7d9ced58_9d77_11e9_8e44_d43d7ebc6f16row1_col0"
#                  class="data row1 col0" >
#                     113
#
#
#
#                 <td id="T_7d9ced58_9d77_11e9_8e44_d43d7ebc6f16row1_col1"
#                  class="data row1 col1" >
#                     $3.20
#
#
#
#                 <td id="T_7d9ced58_9d77_11e9_8e44_d43d7ebc6f16row1_col2"
#                  class="data row1 col2" >
#                     $361.94
#
#
#
#                 <td id="T_7d9ced58_9d77_11e9_8e44_d43d7ebc6f16row1_col3"
#                  class="data row1 col3" >
#                     $4.47
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_7d9ced58_9d77_11e9_8e44_d43d7ebc6f16"
#                  class="row_heading level0 row2" rowspan=1>
#                     Other / Non-Disclosed
#
#
#
#                 <td id="T_7d9ced58_9d77_11e9_8e44_d43d7ebc6f16row2_col0"
#                  class="data row2 col0" >
#                     15
#
#
#
#                 <td id="T_7d9ced58_9d77_11e9_8e44_d43d7ebc6f16row2_col1"
#                  class="data row2 col1" >
#                     $3.35
#
#
#
#                 <td id="T_7d9ced58_9d77_11e9_8e44_d43d7ebc6f16row2_col2"
#                  class="data row2 col2" >
#                     $50.19
#
#
#
#                 <td id="T_7d9ced58_9d77_11e9_8e44_d43d7ebc6f16row2_col3"
#                  class="data row2 col3" >
#                     $4.56
#
#
#             </tr>
#
#         </tbody>
#         </table>

# %% [markdown]
# ## Age Demographics (AD)
# #### Key Takeaways:
# * Most players are in the 20-24 age range (44.79%) with 15-19 falling right behind it (18.58%)

# %%
# Establish the bins and labels
age_bins = [0, 10, 15, 20, 25, 30, 35, 40, 100]
age_labels = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

# Append age binned rows to the no douplicate sn and the original data set using the function "pd.cut()"
no_dup_sn["Age Range"] = pd.cut(no_dup_sn["Age"], age_bins, right=False, labels=age_labels, include_lowest=True)
purchase_data_df["Age Range"] = pd.cut(purchase_data_df["Age"], age_bins, right=False, labels=age_labels, include_lowest=True)

# calc total counts of age groups and percentages
age_groups_AD = no_dup_sn.groupby("Age Range")["Age"].count() # calc counts
age_groups_pct_AD = age_groups_AD / len(no_dup_sn) #calc percentages

# put series data into dataframe
age_demo_analysis = pd.DataFrame({
    "Total Count" : age_groups_AD,
    "Percentage of Players" : age_groups_pct_AD,})

# reorder columns
age_demo_analysis = age_demo_analysis[["Total Count", "Percentage of Players"]]

# format data
age_demo_analysis.style.format({"Percentage of Players" : "{:.02%}"})
# Out:
# C:\Users\Thorish\Anaconda3\lib\site-packages\ipykernel\__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#         <style  type="text/css" >
#
#
#         </style>
#
#         <table id="T_5f52c6fa_9d77_11e9_834b_d43d7ebc6f16" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   Total Count
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   Percentage of Players
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th class="index_name level0" >
#                   Age Range
#
#
#
#                 <th class="blank" >
#
#
#
#
#                 <th class="blank" >
#
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_5f52c6fa_9d77_11e9_834b_d43d7ebc6f16"
#                  class="row_heading level0 row0" rowspan=1>
#                     <10
#
#
#
#                 <td id="T_5f52c6fa_9d77_11e9_834b_d43d7ebc6f16row0_col0"
#                  class="data row0 col0" >
#                     17
#
#
#
#                 <td id="T_5f52c6fa_9d77_11e9_834b_d43d7ebc6f16row0_col1"
#                  class="data row0 col1" >
#                     2.95%
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_5f52c6fa_9d77_11e9_834b_d43d7ebc6f16"
#                  class="row_heading level0 row1" rowspan=1>
#                     10-14
#
#
#
#                 <td id="T_5f52c6fa_9d77_11e9_834b_d43d7ebc6f16row1_col0"
#                  class="data row1 col0" >
#                     22
#
#
#
#                 <td id="T_5f52c6fa_9d77_11e9_834b_d43d7ebc6f16row1_col1"
#                  class="data row1 col1" >
#                     3.82%
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_5f52c6fa_9d77_11e9_834b_d43d7ebc6f16"
#                  class="row_heading level0 row2" rowspan=1>
#                     15-19
#
#
#
#                 <td id="T_5f52c6fa_9d77_11e9_834b_d43d7ebc6f16row2_col0"
#                  class="data row2 col0" >
#                     107
#
#
#
#                 <td id="T_5f52c6fa_9d77_11e9_834b_d43d7ebc6f16row2_col1"
#                  class="data row2 col1" >
#                     18.58%
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_5f52c6fa_9d77_11e9_834b_d43d7ebc6f16"
#                  class="row_heading level0 row3" rowspan=1>
#                     20-24
#
#
#
#                 <td id="T_5f52c6fa_9d77_11e9_834b_d43d7ebc6f16row3_col0"
#                  class="data row3 col0" >
#                     258
#
#
#
#                 <td id="T_5f52c6fa_9d77_11e9_834b_d43d7ebc6f16row3_col1"
#                  class="data row3 col1" >
#                     44.79%
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_5f52c6fa_9d77_11e9_834b_d43d7ebc6f16"
#                  class="row_heading level0 row4" rowspan=1>
#                     25-29
#
#
#
#                 <td id="T_5f52c6fa_9d77_11e9_834b_d43d7ebc6f16row4_col0"
#                  class="data row4 col0" >
#                     77
#
#
#
#                 <td id="T_5f52c6fa_9d77_11e9_834b_d43d7ebc6f16row4_col1"
#                  class="data row4 col1" >
#                     13.37%
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_5f52c6fa_9d77_11e9_834b_d43d7ebc6f16"
#                  class="row_heading level0 row5" rowspan=1>
#                     30-34
#
#
#
#                 <td id="T_5f52c6fa_9d77_11e9_834b_d43d7ebc6f16row5_col0"
#                  class="data row5 col0" >
#                     52
#
#
#
#                 <td id="T_5f52c6fa_9d77_11e9_834b_d43d7ebc6f16row5_col1"
#                  class="data row5 col1" >
#                     9.03%
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_5f52c6fa_9d77_11e9_834b_d43d7ebc6f16"
#                  class="row_heading level0 row6" rowspan=1>
#                     35-39
#
#
#
#                 <td id="T_5f52c6fa_9d77_11e9_834b_d43d7ebc6f16row6_col0"
#                  class="data row6 col0" >
#                     31
#
#
#
#                 <td id="T_5f52c6fa_9d77_11e9_834b_d43d7ebc6f16row6_col1"
#                  class="data row6 col1" >
#                     5.38%
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_5f52c6fa_9d77_11e9_834b_d43d7ebc6f16"
#                  class="row_heading level0 row7" rowspan=1>
#                     40+
#
#
#
#                 <td id="T_5f52c6fa_9d77_11e9_834b_d43d7ebc6f16row7_col0"
#                  class="data row7 col0" >
#                     12
#
#
#
#                 <td id="T_5f52c6fa_9d77_11e9_834b_d43d7ebc6f16row7_col1"
#                  class="data row7 col1" >
#                     2.08%
#
#
#             </tr>
#
#         </tbody>
#         </table>

# %% [markdown]
# ## Purchasing Analysis (Age)
# #### Key Takeaways
# * 20-24 yr olds made the most purchases (365) with a total purchase value of 1,114.06
# * 15-19 yr olds made the second most purchases (136) with a total purchase value of 412.89

# %%
# calculate purchase count, avg purchase price, total purchase value, and avg. total purchase per person by age range
pur_count_PAA =  purchase_data_df.groupby("Age Range")["Purchase ID"].count()
avg_pur_price_PAA =  purchase_data_df.groupby("Age Range")["Price"].mean()
ttl_pur_value_PAA =  purchase_data_df.groupby("Age Range")["Price"].sum()
avg_ttl_pur_value_prsn_PAA =  purchase_data_df.groupby("Age Range")["Price"].sum() / no_dup_sn.groupby("Age Range")["Price"].count() 

# place calculations from above into a data frame 
purchase_analysis_age_PAA = pd.DataFrame({
    "Purchase Count" : pur_count_PAA,
    "Average Purchase Price" : avg_pur_price_PAA,
    "Total Purchase Value" : ttl_pur_value_PAA,
    "Avg Total Purchase per Person" : avg_ttl_pur_value_prsn_PAA})

# reorder columns
purchase_analysis_age_PAA = purchase_analysis_age_PAA[["Purchase Count", "Average Purchase Price", "Total Purchase Value", "Avg Total Purchase per Person"]]

# format data frame
purchase_analysis_age_PAA.style.format({
    "Average Purchase Price" : "${:.2f}",
    "Total Purchase Value" : "${:.2f}",
    "Avg Total Purchase per Person" : "${:.2f}"})
# Out:
#         <style  type="text/css" >
#
#
#         </style>
#
#         <table id="T_2858c422_9d76_11e9_b503_d43d7ebc6f16" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   Purchase Count
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   Average Purchase Price
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   Total Purchase Value
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   Avg Total Purchase per Person
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th class="index_name level0" >
#                   Age Range
#
#
#
#                 <th class="blank" >
#
#
#
#
#                 <th class="blank" >
#
#
#
#
#                 <th class="blank" >
#
#
#
#
#                 <th class="blank" >
#
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_2858c422_9d76_11e9_b503_d43d7ebc6f16"
#                  class="row_heading level0 row0" rowspan=1>
#                     <10
#
#
#
#                 <td id="T_2858c422_9d76_11e9_b503_d43d7ebc6f16row0_col0"
#                  class="data row0 col0" >
#                     23
#
#
#
#                 <td id="T_2858c422_9d76_11e9_b503_d43d7ebc6f16row0_col1"
#                  class="data row0 col1" >
#                     $3.35
#
#
#
#                 <td id="T_2858c422_9d76_11e9_b503_d43d7ebc6f16row0_col2"
#                  class="data row0 col2" >
#                     $77.13
#
#
#
#                 <td id="T_2858c422_9d76_11e9_b503_d43d7ebc6f16row0_col3"
#                  class="data row0 col3" >
#                     $4.54
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_2858c422_9d76_11e9_b503_d43d7ebc6f16"
#                  class="row_heading level0 row1" rowspan=1>
#                     10-14
#
#
#
#                 <td id="T_2858c422_9d76_11e9_b503_d43d7ebc6f16row1_col0"
#                  class="data row1 col0" >
#                     28
#
#
#
#                 <td id="T_2858c422_9d76_11e9_b503_d43d7ebc6f16row1_col1"
#                  class="data row1 col1" >
#                     $2.96
#
#
#
#                 <td id="T_2858c422_9d76_11e9_b503_d43d7ebc6f16row1_col2"
#                  class="data row1 col2" >
#                     $82.78
#
#
#
#                 <td id="T_2858c422_9d76_11e9_b503_d43d7ebc6f16row1_col3"
#                  class="data row1 col3" >
#                     $3.76
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_2858c422_9d76_11e9_b503_d43d7ebc6f16"
#                  class="row_heading level0 row2" rowspan=1>
#                     15-19
#
#
#
#                 <td id="T_2858c422_9d76_11e9_b503_d43d7ebc6f16row2_col0"
#                  class="data row2 col0" >
#                     136
#
#
#
#                 <td id="T_2858c422_9d76_11e9_b503_d43d7ebc6f16row2_col1"
#                  class="data row2 col1" >
#                     $3.04
#
#
#
#                 <td id="T_2858c422_9d76_11e9_b503_d43d7ebc6f16row2_col2"
#                  class="data row2 col2" >
#                     $412.89
#
#
#
#                 <td id="T_2858c422_9d76_11e9_b503_d43d7ebc6f16row2_col3"
#                  class="data row2 col3" >
#                     $3.86
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_2858c422_9d76_11e9_b503_d43d7ebc6f16"
#                  class="row_heading level0 row3" rowspan=1>
#                     20-24
#
#
#
#                 <td id="T_2858c422_9d76_11e9_b503_d43d7ebc6f16row3_col0"
#                  class="data row3 col0" >
#                     365
#
#
#
#                 <td id="T_2858c422_9d76_11e9_b503_d43d7ebc6f16row3_col1"
#                  class="data row3 col1" >
#                     $3.05
#
#
#
#                 <td id="T_2858c422_9d76_11e9_b503_d43d7ebc6f16row3_col2"
#                  class="data row3 col2" >
#                     $1114.06
#
#
#
#                 <td id="T_2858c422_9d76_11e9_b503_d43d7ebc6f16row3_col3"
#                  class="data row3 col3" >
#                     $4.32
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_2858c422_9d76_11e9_b503_d43d7ebc6f16"
#                  class="row_heading level0 row4" rowspan=1>
#                     25-29
#
#
#
#                 <td id="T_2858c422_9d76_11e9_b503_d43d7ebc6f16row4_col0"
#                  class="data row4 col0" >
#                     101
#
#
#
#                 <td id="T_2858c422_9d76_11e9_b503_d43d7ebc6f16row4_col1"
#                  class="data row4 col1" >
#                     $2.90
#
#
#
#                 <td id="T_2858c422_9d76_11e9_b503_d43d7ebc6f16row4_col2"
#                  class="data row4 col2" >
#                     $293.00
#
#
#
#                 <td id="T_2858c422_9d76_11e9_b503_d43d7ebc6f16row4_col3"
#                  class="data row4 col3" >
#                     $3.81
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_2858c422_9d76_11e9_b503_d43d7ebc6f16"
#                  class="row_heading level0 row5" rowspan=1>
#                     30-34
#
#
#
#                 <td id="T_2858c422_9d76_11e9_b503_d43d7ebc6f16row5_col0"
#                  class="data row5 col0" >
#                     73
#
#
#
#                 <td id="T_2858c422_9d76_11e9_b503_d43d7ebc6f16row5_col1"
#                  class="data row5 col1" >
#                     $2.93
#
#
#
#                 <td id="T_2858c422_9d76_11e9_b503_d43d7ebc6f16row5_col2"
#                  class="data row5 col2" >
#                     $214.00
#
#
#
#                 <td id="T_2858c422_9d76_11e9_b503_d43d7ebc6f16row5_col3"
#                  class="data row5 col3" >
#                     $4.12
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_2858c422_9d76_11e9_b503_d43d7ebc6f16"
#                  class="row_heading level0 row6" rowspa

# %% [markdown]
# ## Top Spenders
# #### Key Takeaways:
# * "Lisosia93" is the biggest spender, buying 5 items worth in total to 18.96

# %%
# Calculate Purchase Count, Average Purchase Price, and Total Purchase Value
pur_count_TP = purchase_data_df.groupby("SN")["Price"].count()
avg_pur_price_TP = purchase_data_df.groupby("SN")["Price"].mean()
ttl_pur_price_TP = purchase_data_df.groupby("SN")["Price"].sum()

# place calculations from above into a data frame 
top_spender_analysis_TP = pd.DataFrame({
    "Purchase Count" : pur_count_TP,
    "Average Purchase Price" : avg_pur_price_TP,
    "Total Purchase Value" : ttl_pur_price_TP})

# reorder columns
top_spender_analysis_TP = top_spender_analysis_TP[["Purchase Count", "Average Purchase Price", "Total Purchase Value"]]

# sort values in "Total Purchase Value" column in descending order 
sorted_TP = top_spender_analysis_TP.sort_values("Total Purchase Value", ascending=False).head()

# format data frame
sorted_TP.style.format({
    "Average Purchase Price" : '${:,.2f}'.format,
    "Total Purchase Value" : '${:,.2f}'.format})
# Out:
#         <style  type="text/css" >
#
#
#         </style>
#
#         <table id="T_5cd4bffe_9d76_11e9_a69b_d43d7ebc6f16" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   Purchase Count
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   Average Purchase Price
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   Total Purchase Value
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th class="index_name level0" >
#                   SN
#
#
#
#                 <th class="blank" >
#
#
#
#
#                 <th class="blank" >
#
#
#
#
#                 <th class="blank" >
#
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_5cd4bffe_9d76_11e9_a69b_d43d7ebc6f16"
#                  class="row_heading level0 row0" rowspan=1>
#                     Lisosia93
#
#
#
#                 <td id="T_5cd4bffe_9d76_11e9_a69b_d43d7ebc6f16row0_col0"
#                  class="data row0 col0" >
#                     5
#
#
#
#                 <td id="T_5cd4bffe_9d76_11e9_a69b_d43d7ebc6f16row0_col1"
#                  class="data row0 col1" >
#                     $3.79
#
#
#
#                 <td id="T_5cd4bffe_9d76_11e9_a69b_d43d7ebc6f16row0_col2"
#                  class="data row0 col2" >
#                     $18.96
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_5cd4bffe_9d76_11e9_a69b_d43d7ebc6f16"
#                  class="row_heading level0 row1" rowspan=1>
#                     Idastidru52
#
#
#
#                 <td id="T_5cd4bffe_9d76_11e9_a69b_d43d7ebc6f16row1_col0"
#                  class="data row1 col0" >
#                     4
#
#
#
#                 <td id="T_5cd4bffe_9d76_11e9_a69b_d43d7ebc6f16row1_col1"
#                  class="data row1 col1" >
#                     $3.86
#
#
#
#                 <td id="T_5cd4bffe_9d76_11e9_a69b_d43d7ebc6f16row1_col2"
#                  class="data row1 col2" >
#                     $15.45
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_5cd4bffe_9d76_11e9_a69b_d43d7ebc6f16"
#                  class="row_heading level0 row2" rowspan=1>
#                     Chamjask73
#
#
#
#                 <td id="T_5cd4bffe_9d76_11e9_a69b_d43d7ebc6f16row2_col0"
#                  class="data row2 col0" >
#                     3
#
#
#
#                 <td id="T_5cd4bffe_9d76_11e9_a69b_d43d7ebc6f16row2_col1"
#                  class="data row2 col1" >
#                     $4.61
#
#
#
#                 <td id="T_5cd4bffe_9d76_11e9_a69b_d43d7ebc6f16row2_col2"
#                  class="data row2 col2" >
#                     $13.83
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_5cd4bffe_9d76_11e9_a69b_d43d7ebc6f16"
#                  class="row_heading level0 row3" rowspan=1>
#                     Iral74
#
#
#
#                 <td id="T_5cd4bffe_9d76_11e9_a69b_d43d7ebc6f16row3_col0"
#                  class="data row3 col0" >
#                     4
#
#
#
#                 <td id="T_5cd4bffe_9d76_11e9_a69b_d43d7ebc6f16row3_col1"
#                  class="data row3 col1" >
#                     $3.40
#
#
#
#                 <td id="T_5cd4bffe_9d76_11e9_a69b_d43d7ebc6f16row3_col2"
#                  class="data row3 col2" >
#                     $13.62
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_5cd4bffe_9d76_11e9_a69b_d43d7ebc6f16"
#                  class="row_heading level0 row4" rowspan=1>
#                     Iskadarya95
#
#
#
#                 <td id="T_5cd4bffe_9d76_11e9_a69b_d43d7ebc6f16row4_col0"
#                  class="data row4 col0" >
#                     3
#
#
#
#                 <td id="T_5cd4bffe_9d76_11e9_a69b_d43d7ebc6f16row4_col1"
#                  class="data row4 col1" >
#                     $4.37
#
#
#
#                 <td id="T_5cd4bffe_9d76_11e9_a69b_d43d7ebc6f16row4_col2"
#                  class="data row4 col2" >
#                     $13.10
#
#
#             </tr>
#
#         </tbody>
#         </table>

# %% [markdown]
# ## Most Popular Items
# #### Key Takeaways:
# * The most popular item is the "Oathbreaker, Last Hope of the Breaking Storm" with 12 total purchases and total purchase value of 50.76

# %%
# calculate Purchase Count, Item Price, and Total Purchase Value
pur_count_MPoI = purchase_data_df.groupby(["Item ID", "Item Name"])["Item ID"].count()
item_price_MPoI = purchase_data_df.groupby(["Item ID", "Item Name"])["Price"].mean()
ttl_pur_value_MPoI = purchase_data_df.groupby(["Item ID", "Item Name"])["Price"].sum()

# place calculations from above into a data frame 
most_popular_items_MPoI = pd.DataFrame({
    "Purchase Count" : pur_count_MPoI,
    "Item Price" : item_price_MPoI,
    "Total Purchase Value" : ttl_pur_value_MPoI})

# reorder columns
most_popular_items_MPoI = most_popular_items_MPoI[["Purchase Count", "Item Price", "Total Purchase Value"]]

# sort values in "Total Purchase Value" column in descending order 
sorted_most_popular_items_MPoI = most_popular_items_MPoI.sort_values("Purchase Count", ascending=False).head()

# format data frame
sorted_most_popular_items_MPoI.style.format({
    "Item Price" : '${:,.2f}'.format,
    "Total Purchase Value" : '${:,.2f}'.format})
# Out:
#         <style  type="text/css" >
#
#
#         </style>
#
#         <table id="T_e09d87a2_9d76_11e9_9946_d43d7ebc6f16" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank" >
#
#
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   Purchase Count
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   Item Price
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   Total Purchase Value
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th class="index_name level0" >
#                   Item ID
#
#
#
#                 <th class="index_name level1" >
#                   Item Name
#
#
#
#                 <th class="blank" >
#
#
#
#
#                 <th class="blank" >
#
#
#
#
#                 <th class="blank" >
#
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_e09d87a2_9d76_11e9_9946_d43d7ebc6f16"
#                  class="row_heading level0 row0" rowspan=1>
#                     178
#
#
#
#                 <th id="T_e09d87a2_9d76_11e9_9946_d43d7ebc6f16"
#                  class="row_heading level1 row0" rowspan=1>
#                     Oathbreaker, Last Hope of the Breaking Storm
#
#
#
#                 <td id="T_e09d87a2_9d76_11e9_9946_d43d7ebc6f16row0_col0"
#                  class="data row0 col0" >
#                     12
#
#
#
#                 <td id="T_e09d87a2_9d76_11e9_9946_d43d7ebc6f16row0_col1"
#                  class="data row0 col1" >
#                     $4.23
#
#
#
#                 <td id="T_e09d87a2_9d76_11e9_9946_d43d7ebc6f16row0_col2"
#                  class="data row0 col2" >
#                     $50.76
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_e09d87a2_9d76_11e9_9946_d43d7ebc6f16"
#                  class="row_heading level0 row1" rowspan=1>
#                     145
#
#
#
#                 <th id="T_e09d87a2_9d76_11e9_9946_d43d7ebc6f16"
#                  class="row_heading level1 row1" rowspan=1>
#                     Fiery Glass Crusader
#
#
#
#                 <td id="T_e09d87a2_9d76_11e9_9946_d43d7ebc6f16row1_col0"
#                  class="data row1 col0" >
#                     9
#
#
#
#                 <td id="T_e09d87a2_9d76_11e9_9946_d43d7ebc6f16row1_col1"
#                  class="data row1 col1" >
#                     $4.58
#
#
#
#                 <td id="T_e09d87a2_9d76_11e9_9946_d43d7ebc6f16row1_col2"
#                  class="data row1 col2" >
#                     $41.22
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_e09d87a2_9d76_11e9_9946_d43d7ebc6f16"
#                  class="row_heading level0 row2" rowspan=1>
#                     108
#
#
#
#                 <th id="T_e09d87a2_9d76_11e9_9946_d43d7ebc6f16"
#                  class="row_heading level1 row2" rowspan=1>
#                     Extraction, Quickblade Of Trembling Hands
#
#
#
#                 <td id="T_e09d87a2_9d76_11e9_9946_d43d7ebc6f16row2_col0"
#                  class="data row2 col0" >
#                     9
#
#
#
#                 <td id="T_e09d87a2_9d76_11e9_9946_d43d7ebc6f16row2_col1"
#                  class="data row2 col1" >
#                     $3.53
#
#
#
#                 <td id="T_e09d87a2_9d76_11e9_9946_d43d7ebc6f16row2_col2"
#                  class="data row2 col2" >
#                     $31.77
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_e09d87a2_9d76_11e9_9946_d43d7ebc6f16"
#                  class="row_heading level0 row3" rowspan=1>
#                     82
#
#
#
#                 <th id="T_e09d87a2_9d76_11e9_9946_d43d7ebc6f16"
#                  class="row_heading level1 row3" rowspan=1>
#                     Nirvana
#
#
#
#                 <td id="T_e09d87a2_9d76_11e9_9946_d43d7ebc6f16row3_col0"
#                  class="data row3 col0" >
#                     9
#
#
#
#                 <td id="T_e09d87a2_9d76_11e9_9946_d43d7ebc6f16row3_col1"
#                  class="data row3 col1" >
#                     $4.90
#
#
#
#                 <td id="T_e09d87a2_9d76_11e9_9946_d43d7ebc6f16row3_col2"
#                  class="data row3 col2" >
#                     $44.10
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_e09d87a2_9d76_11e9_9946_d43d7ebc6f16"
#                  class="row_heading level0 row4" rowspan=1>
#                     19
#
#
#
#                 <th id="T_e09d87a2_9d76_11e9_9946_d43d7ebc6f16"
#                  class="row_heading level1 row4" rowspan=1>
#                     Pursuit, Cudgel of Necromancy
#
#
#
#                 <td id="T_e09d87a2_9d76_11e9_9946_d43d7ebc6f16row4_col0"
#                  class="data row4 col0" >
#                     8
#
#
#
#                 <td id="T_e09d87a2_9d76_11e9_9946_d43d7ebc6f16row4_col1"
#                  class="data row4 col1" >
#                     $1.02
#
#
#
#                 <td id="T_e09d87a2_9d76_11e9_9946_d43d7ebc6f16row4_col2"
#                  class="data row4 col2" >
#                     $8.16
#
#
#             </tr>
#
#         </tbody>
#         </table>

# %% [markdown]
# ## Most Profitable Items
# #### Key Takeaways:
# * The most profitable items are Oathbreaker [...] (50.76), Nirvana (44.10), and Fiery Glass Crusader (41.22)

# %%
# sort previous data set in descending order by Total Purchase Value
most_profitable_items = most_popular_items_MPoI.sort_values("Total Purchase Value", ascending = False).head()

# format data frame
most_profitable_items.style.format({
    "Price" : '${:,.2f}'.format,
    "Item Price" : '${:,.2f}'.format,
    "Total Purchase Value" : '${:,.2f}'.format})
# Out:
#         <style  type="text/css" >
#
#
#         </style>
#
#         <table id="T_f0bee8cc_9d76_11e9_b28c_d43d7ebc6f16" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank" >
#
#
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   Purchase Count
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   Item Price
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   Total Purchase Value
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th class="index_name level0" >
#                   Item ID
#
#
#
#                 <th class="index_name level1" >
#                   Item Name
#
#
#
#                 <th class="blank" >
#
#
#
#
#                 <th class="blank" >
#
#
#
#
#                 <th class="blank" >
#
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_f0bee8cc_9d76_11e9_b28c_d43d7ebc6f16"
#                  class="row_heading level0 row0" rowspan=1>
#                     178
#
#
#
#                 <th id="T_f0bee8cc_9d76_11e9_b28c_d43d7ebc6f16"
#                  class="row_heading level1 row0" rowspan=1>
#                     Oathbreaker, Last Hope of the Breaking Storm
#
#
#
#                 <td id="T_f0bee8cc_9d76_11e9_b28c_d43d7ebc6f16row0_col0"
#                  class="data row0 col0" >
#                     12
#
#
#
#                 <td id="T_f0bee8cc_9d76_11e9_b28c_d43d7ebc6f16row0_col1"
#                  class="data row0 col1" >
#                     $4.23
#
#
#
#                 <td id="T_f0bee8cc_9d76_11e9_b28c_d43d7ebc6f16row0_col2"
#                  class="data row0 col2" >
#                     $50.76
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_f0bee8cc_9d76_11e9_b28c_d43d7ebc6f16"
#                  class="row_heading level0 row1" rowspan=1>
#                     82
#
#
#
#                 <th id="T_f0bee8cc_9d76_11e9_b28c_d43d7ebc6f16"
#                  class="row_heading level1 row1" rowspan=1>
#                     Nirvana
#
#
#
#                 <td id="T_f0bee8cc_9d76_11e9_b28c_d43d7ebc6f16row1_col0"
#                  class="data row1 col0" >
#                     9
#
#
#
#                 <td id="T_f0bee8cc_9d76_11e9_b28c_d43d7ebc6f16row1_col1"
#                  class="data row1 col1" >
#                     $4.90
#
#
#
#                 <td id="T_f0bee8cc_9d76_11e9_b28c_d43d7ebc6f16row1_col2"
#                  class="data row1 col2" >
#                     $44.10
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_f0bee8cc_9d76_11e9_b28c_d43d7ebc6f16"
#                  class="row_heading level0 row2" rowspan=1>
#                     145
#
#
#
#                 <th id="T_f0bee8cc_9d76_11e9_b28c_d43d7ebc6f16"
#                  class="row_heading level1 row2" rowspan=1>
#                     Fiery Glass Crusader
#
#
#
#                 <td id="T_f0bee8cc_9d76_11e9_b28c_d43d7ebc6f16row2_col0"
#                  class="data row2 col0" >
#                     9
#
#
#
#                 <td id="T_f0bee8cc_9d76_11e9_b28c_d43d7ebc6f16row2_col1"
#                  class="data row2 col1" >
#                     $4.58
#
#
#
#                 <td id="T_f0bee8cc_9d76_11e9_b28c_d43d7ebc6f16row2_col2"
#                  class="data row2 col2" >
#                     $41.22
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_f0bee8cc_9d76_11e9_b28c_d43d7ebc6f16"
#                  class="row_heading level0 row3" rowspan=1>
#                     92
#
#
#
#                 <th id="T_f0bee8cc_9d76_11e9_b28c_d43d7ebc6f16"
#                  class="row_heading level1 row3" rowspan=1>
#                     Final Critic
#
#
#
#                 <td id="T_f0bee8cc_9d76_11e9_b28c_d43d7ebc6f16row3_col0"
#                  class="data row3 col0" >
#                     8
#
#
#
#                 <td id="T_f0bee8cc_9d76_11e9_b28c_d43d7ebc6f16row3_col1"
#                  class="data row3 col1" >
#                     $4.88
#
#
#
#                 <td id="T_f0bee8cc_9d76_11e9_b28c_d43d7ebc6f16row3_col2"
#                  class="data row3 col2" >
#                     $39.04
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_f0bee8cc_9d76_11e9_b28c_d43d7ebc6f16"
#                  class="row_heading level0 row4" rowspan=1>
#                     103
#
#
#
#                 <th id="T_f0bee8cc_9d76_11e9_b28c_d43d7ebc6f16"
#                  class="row_heading level1 row4" rowspan=1>
#                     Singed Scalpel
#
#
#
#                 <td id="T_f0bee8cc_9d76_11e9_b28c_d43d7ebc6f16row4_col0"
#                  class="data row4 col0" >
#                     8
#
#
#
#                 <td id="T_f0bee8cc_9d76_11e9_b28c_d43d7ebc6f16row4_col1"
#                  class="data row4 col1" >
#                     $4.35
#
#
#
#                 <td id="T_f0bee8cc_9d76_11e9_b28c_d43d7ebc6f16row4_col2"
#                  class="data row4 col2" >
#                     $34.80
#
#
#             </tr>
#
#         </tbody>
#         </table>
